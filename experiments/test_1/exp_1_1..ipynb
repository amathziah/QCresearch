# %%
# ------------------------------
# Setup paths and imports
# ------------------------------
import sys
from pathlib import Path

# Point to the src directory
project_root = Path().resolve().parents[1]  # adjust if notebook location changes
src_path = project_root / "src"
sys.path.append(str(src_path))

# ------------------------------
# Standard imports
# ------------------------------
from qiskit import Aer, QuantumCircuit
from qiskit.circuit import Parameter, ParameterVector
from qiskit.opflow import StateFn, PauliSumOp, AerPauliExpectation, ListOp, Gradient, OperatorStateFn
from qiskit.utils import QuantumInstance

import matplotlib.pyplot as plt
import numpy as np

# ------------------------------
# Your local modules
# ------------------------------
from qiskit_utils import BinaryObjectiveFunction
from data_utils import circle, plot_data, generate_ds

# ------------------------------
# Random seed
# ------------------------------
np.random.seed(42)

# ------------------------------
# Example: Generate a toy dataset
# ------------------------------
X, y = generate_ds(n_samples=50, noise=0.1)
plot_data(X, y)

# %%
# Generate training and test data
num_training = 200
num_test = 2000

X_train, y_train, new_y_train = generate_ds(num_training)
X_test, y_test, new_y_test= generate_ds(num_test)

# %%
# set method to calculcate expected values
expval = AerPauliExpectation()

# define gradient method
gradient = Gradient()

# define quantum instances (statevector and sample based)
qi_sv = QuantumInstance(Aer.get_backend('aer_simulator_statevector'))

# %%
from qiskit_machine_learning.neural_networks import OpflowQNN

# construct parametrized circuit
inputs = ParameterVector('input', length=4) # 1 extra for label
weights = ParameterVector('weight', length=9)

# 1qubit classifier
qc1 = QuantumCircuit(1)
qc1.u(inputs[0],inputs[1],inputs[2], 0)
qc1.u(weights[0],weights[1],weights[2], 0)
qc1.u(inputs[0],inputs[1],inputs[2], 0)
qc1.u(weights[3],weights[4],weights[5], 0)
qc1.u(inputs[0],inputs[1],inputs[2], 0)
qc1.u(weights[6],weights[7],weights[8], 0)
qc_sfn1 = StateFn(qc1)

H1 = StateFn(PauliSumOp.from_list([('Z', 1.0)]))
H2 = StateFn(PauliSumOp.from_list([('Z', -1.0)]))

op1 = ~H1 @ (qc_sfn1)
op2 = ~H2 @ (qc_sfn1)
print(op1)
# Out:
# ComposedOp([
#   OperatorMeasurement(1.0 * Z),
#   CircuitStateFn(
#      ┌───────────────────────────────┐┌──────────────────────────────────┐»
#   q: ┤ U(input[0],input[1],input[2]) ├┤ U(weight[0],weight[1],weight[2]) ├»
#      └───────────────────────────────┘└──────────────────────────────────┘»
#   «   ┌───────────────────────────────┐┌──────────────────────────────────┐»
#   «q: ┤ U(input[0],input[1],input[2]) ├┤ U(weight[3],weight[4],weight[5]) ├»
#   «   └───────────────────────────────┘└──────────────────────────────────┘»
#   «   ┌───────────────────────────────┐┌──────────────────────────────────┐
#   «q: ┤ U(input[0],input[1],input[2]) ├┤ U(weight[6],weight[7],weight[8]) ├
#   «   └───────────────────────────────┘└──────────────────────────────────┘
#   )
# ])

# %%
# construct OpflowQNN with the operator, the input parameters, the weight parameters,
# the expected value, gradient, and quantum instance.
qnn1 = OpflowQNN(op1, inputs, weights, expval, gradient, qi_sv)
qnn2 = OpflowQNN(op2, inputs, weights, expval, gradient, qi_sv)

# %%
from qiskit.algorithms.optimizers import ADAM, L_BFGS_B
from qiskit_machine_learning.utils.loss_functions import L2Loss
from qiskit.utils import algorithm_globals
import numpy as np

# Track losses
losses = []

# Callback function
def callback_fn(avg_loss, weights):
    print("weights: ", weights)
    print("loss: ", avg_loss)
    losses.append(avg_loss)

# Initialize the objective function
function = BinaryObjectiveFunction(X_train, new_y_train, qnn1, qnn2, L2Loss(), callback_fn)

# Choose optimizer
optimizer = L_BFGS_B(maxiter=50)
# optimizer = ADAM(maxiter=30, lr=0.8)

# Initial random weights
initial_point = algorithm_globals.random.random(qnn1.num_weights)

# Run optimization
fit_result = optimizer.minimize(
    fun=function.objective,   # objective function
    x0=initial_point,         # starting point
    jac=function.gradient      # gradient function
)

# Optimized weights
optimal_weights = fit_result.x
print("Optimized weights:", optimal_weights)
print("Final loss:", fit_result.fun)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 26
#      23 initial_point = algorithm_globals.random.random(qnn1.num_weights)
#      25 # Run optimization
# ---> 26 fit_result = optimizer.minimize(
#      27     fun=function.objective,   # objective function
#      28     x0=initial_point,         # starting point
#      29     jac=function.gradient      # gradient function
#      30 )
#      32 # Optimized weights
#      33 optimal_weights = fit_result.x
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit/algorithms/optimizers/scipy_optimizer.py:148, in SciPyOptimizer.minimize(self, fun, x0, jac, bounds)
#     145     swapped_deprecated_args = True
#     146     self._options["maxfun"] = self._options.pop("maxiter")
# --> 148 raw_result = minimize(
#     149     fun=fun,
#     150     x0=x0,
#     151     method=self._method,
#     152     jac=jac,
#     153     bounds=bounds,
#     154     options=self._options,
#     155     **self._kwargs,
#     156 )
#     157 if swapped_deprecated_args:
#     158     self._options["maxiter"] = self._options.pop("maxfun")
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/scipy/optimize/_minimize.py:738, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     735     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     736                              **options)
#     737 elif meth == 'l-bfgs-b':
# --> 738     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     739                            callback=callback, **options)
#     740 elif meth == 'tnc':
#     741     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     742                         **options)
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py:386, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     383     x0 = np.clip(x0, bounds[0], bounds[1])
#     385 # _prepare_scalar_function can use bounds=None to represent no bounds
# --> 386 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     387                               bounds=bounds,
#     388                               finite_diff_rel_step=finite_diff_rel_step)
#     390 func_and_grad = sf.fun_and_grad
#     392 nbd = zeros(n, np.int32)
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/scipy/optimize/_optimize.py:291, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     287     bounds = (-np.inf, np.inf)
#     289 # ScalarFunction caches. Reuse of fun(x) during grad
#     290 # calculation reduces overall function evaluations.
# --> 291 sf = ScalarFunction(fun, x0, args, grad, hess,
#     292                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     294 return sf
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:232, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     225 # Initial gradient evaluation
#     226 self._wrapped_grad, self._ngev = _wrapper_grad(
#     227     grad,
#     228     fun=self._wrapped_fun,
#     229     args=args,
#     230     finite_diff_options=finite_diff_options
#     231 )
# --> 232 self._update_grad()
#     234 # Hessian evaluation
#     235 if callable(hess):
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:307, in ScalarFunction._update_grad(self)
#     305 if self._orig_grad in FD_METHODS:
#     306     self._update_fun()
# --> 307 self.g = self._wrapped_grad(self.x, f0=self.f)
#     308 self.g_updated = True
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:42, in _wrapper_grad.<locals>.wrapped(x, **kwds)
#      39 def wrapped(x, **kwds):
#      40     # kwds present to give function same signature as numdiff variant
#      41     ncalls[0] += 1
# ---> 42     return np.atleast_1d(grad(np.copy(x), *args))
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit/algorithms/optimizers/scipy_optimizer.py:172, in SciPyOptimizer._wrap_gradient.<locals>.wrapped_gradient(x)
#     171 def wrapped_gradient(x):
# --> 172     gradient = gradient_function(x)
#     173     if isinstance(gradient, np.ndarray):
#     174         return gradient.tolist()
#
# File ~/Desktop/QCresearch/single-qubit-qnn/src/qiskit_utils.py:136, in BinaryObjectiveFunction.gradient(self, weights)
#     133     _, wg = self._neural_network1.backward(xi, weights)
#     134 elif xi[-1] == -1:
#     135     # weight grad is of shape (N, 1, num_weights)
# --> 136     _, wg = self._neural_network2.backward(xi, weights)
#     137 else:
#     138     raise NotImplementedError
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit_machine_learning/neural_networks/neural_network.py:252, in NeuralNetwork.backward(self, input_data, weights)
#     250 input_, shape = self._validate_input(input_data)
#     251 weights_ = self._validate_weights(weights)
# --> 252 input_grad, weight_grad = self._backward(input_, weights_)
#     254 input_grad_reshaped, weight_grad_reshaped = self._validate_backward_output(
#     255     input_grad, weight_grad, shape
#     256 )
#     258 return input_grad_reshaped, weight_grad_reshaped
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit_machine_learning/neural_networks/opflow_qnn.py:254, in OpflowQNN._backward(self, input_data, weights)
#     251         grad = self._evaluate_operator(converted_op, num_samples, param_values)
#     252     else:
#     253         # all parameters are bound by CircuitSampler, so we evaluate the operator directly
# --> 254         grad = np.asarray(converted_op.eval())
#     255 else:
#     256     # we evaluate gradient operator for each sample separately, so we create a list of operators.
#     257     grad = self._evaluate_operator(
#     258         [self._gradient_operator] * num_samples, num_samples, param_values
#     259     )
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit/opflow/list_ops/list_op.py:433, in ListOp.eval(self, front)
#     428 if not self.distributive:
#     429     raise NotImplementedError(
#     430         "ListOp's eval function is only defined for distributive ListOps."
#     431     )
# --> 433 evals = [op.eval(front) for op in self.oplist]
#     435 # Handle application of combo_fn for DictStateFn resp VectorStateFn operators
#     436 if self._combo_fn is not None:  # If not using default.
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit/opflow/list_ops/list_op.py:433, in <listcomp>(.0)
#     428 if not self.distributive:
#     429     raise NotImplementedError(
#     430         "ListOp's eval function is only defined for distributive ListOps."
#     431     )
# --> 433 evals = [op.eval(front) for op in self.oplist]
#     435 # Handle application of combo_fn for DictStateFn resp VectorStateFn operators
#     436 if self._combo_fn is not None:  # If not using default.
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit/opflow/list_ops/list_op.py:433, in ListOp.eval(self, front)
#     428 if not self.distributive:
#     429     raise NotImplementedError(
#     430         "ListOp's eval function is only defined for distributive ListOps."
#     431     )
# --> 433 evals = [op.eval(front) for op in self.oplist]
#     435 # Handle application of combo_fn for DictStateFn resp VectorStateFn operators
#     436 if self._combo_fn is not None:  # If not using default.
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit/opflow/list_ops/list_op.py:433, in <listcomp>(.0)
#     428 if not self.distributive:
#     429     raise NotImplementedError(
#     430         "ListOp's eval function is only defined for distributive ListOps."
#     431     )
# --> 433 evals = [op.eval(front) for op in self.oplist]
#     435 # Handle application of combo_fn for DictStateFn resp VectorStateFn operators
#     436 if self._combo_fn is not None:  # If not using default.
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit/opflow/list_ops/list_op.py:433, in ListOp.eval(self, front)
#     428 if not self.distributive:
#     429     raise NotImplementedError(
#     430         "ListOp's eval function is only defined for distributive ListOps."
#     431     )
# --> 433 evals = [op.eval(front) for op in self.oplist]
#     435 # Handle application of combo_fn for DictStateFn resp VectorStateFn operators
#     436 if self._combo_fn is not None:  # If not using default.
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit/opflow/list_ops/list_op.py:433, in <listcomp>(.0)
#     428 if not self.distributive:
#     429     raise NotImplementedError(
#     430         "ListOp's eval function is only defined for distributive ListOps."
#     431     )
# --> 433 evals = [op.eval(front) for op in self.oplist]
#     435 # Handle application of combo_fn for DictStateFn resp VectorStateFn operators
#     436 if self._combo_fn is not None:  # If not using default.
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit/opflow/list_ops/composed_op.py:141, in ComposedOp.eval(self, front)
#     138 elif front:
#     139     eval_list = [StateFn(front, is_measurement=True)] + eval_list  # type: ignore
# --> 141 return reduce(tree_recursive_eval, reversed(eval_list))
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit/opflow/list_ops/composed_op.py:131, in ComposedOp.eval.<locals>.tree_recursive_eval(r, l_arg)
#     129     return [tree_recursive_eval(r_op, l_arg) for r_op in r]
#     130 else:
# --> 131     return l_arg.eval(r)
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit/opflow/state_fns/operator_state_fn.py:251, in OperatorStateFn.eval(self, front)
#     248 if isinstance(front, CircuitStateFn):
#     249     front = front.eval()
# --> 251 return front.adjoint().eval(cast(OperatorBase, self.primitive.eval(front))) * self.coeff
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit/opflow/primitive_ops/pauli_op.py:274, in PauliOp.eval(self, front)
#     272     # Covers VectorStateFn and OperatorStateFn
#     273     elif isinstance(front, StateFn):
# --> 274         new_front = self.to_matrix_op().eval(front.to_matrix_op())
#     276 return new_front
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit/opflow/primitive_ops/primitive_op.py:266, in PrimitiveOp.to_matrix_op(self, massive)
#     264 op = self.copy()
#     265 op._coeff = 1
# --> 266 prim_mat = op.to_matrix(massive=massive)
#     267 from .matrix_op import MatrixOp
#     269 return MatrixOp(prim_mat, coeff=coeff)
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit/opflow/primitive_ops/pauli_op.py:186, in PauliOp.to_matrix(self, massive)
#     184 def to_matrix(self, massive: bool = False) -> np.ndarray:
#     185     OperatorBase._check_massive("to_matrix", True, self.num_qubits, massive)
# --> 186     return self.primitive.to_matrix() * self.coeff
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit/quantum_info/operators/symplectic/pauli.py:435, in Pauli.to_matrix(self, sparse)
#     425 def to_matrix(self, sparse=False):
#     426     r"""Convert to a Numpy array or sparse CSR matrix.
#     427
#     428     Args:
#    (...)
#     433         array: The Pauli matrix.
#     434     """
# --> 435     return self._to_matrix(self.z, self.x, self._phase[0], sparse=sparse)
#
# File ~/Desktop/QCresearch/single-qubit-qnn/venv/lib/python3.10/site-packages/qiskit/quantum_info/operators/symplectic/base_pauli.py:430, in BasePauli._to_matrix(z, x, phase, group_phase, sparse)
#     427 z_indices = np.asarray(z).dot(twos_array)
#     429 indptr = np.arange(dim + 1, dtype=np.uint)
# --> 430 indices = indptr ^ x_indices
#     431 if phase:
#     432     coeff = (-1j) ** phase
#
# TypeError: ufunc 'bitwise_xor' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
plt.plot(losses)

# %%
ws = [-0.91709316,  1.57980935, -1.61740473,  1.1182353,  -1.56539397,  1.52962569,
 -1.52987669,  0.00201624,  1.47818211]

from test_utils import get_metrics
y_predict, y_tensor, accuracy, [tp, tn, fp, fn] = get_metrics(X_train, qnn1, ws)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       1 ws = [-0.91709316,  1.57980935, -1.61740473,  1.1182353,  -1.56539397,  1.52962569,
#       2  -1.52987669,  0.00201624,  1.47818211]
# ----> 4 from test_utils import get_metrics
#       5 y_predict, y_tensor, accuracy, [tp, tn, fp, fn] = get_metrics(X_train, qnn1, ws)
#
# ModuleNotFoundError: No module named 'test_utils'

# %%
# print('Accuracy:', acc/len(y_tensor))
plt.figure(figsize=(8,8))
for x, y_target, y_ in zip(X_train, y_tensor, y_predict):
    if y_ == 1:
        plt.plot(x[0], x[1], 'bo')
    else:
        plt.plot(x[0], x[1], 'go')
    if y_target != y_:
        plt.scatter(x[0], x[1], s=200, facecolors='none', edgecolors='r', linewidths=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 # print('Accuracy:', acc/len(y_tensor))
#       2 plt.figure(figsize=(8,8))
# ----> 3 for x, y_target, y_ in zip(X_train, y_tensor, y_predict):
#       4     if y_ == 1:
#       5         plt.plot(x[0], x[1], 'bo')
#
# NameError: name 'y_tensor' is not defined

# %%
y_predict, y_tensor, accuracy, [tp, tn, fp, fn] = get_metrics(X_test, qnn1, ws)

# %%
# print('Accuracy:', acc/len(y_tensor))
plt.figure(figsize=(8,8))
for x, y_target, y_ in zip(X_test, y_tensor, y_predict):
    if y_ == 1:
        plt.plot(x[0], x[1], 'bo')
    else:
        plt.plot(x[0], x[1], 'go')
    if y_target != y_:
        plt.scatter(x[0], x[1], s=200, facecolors='none', edgecolors='r', linewidths=1)
plt.show()
# Out:
# Running cells with 'Python 3.13.0' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
